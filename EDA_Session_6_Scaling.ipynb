# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
num=visa_df.select_dtypes(exclude='object').columns
cat=visa_df.select_dtypes(include='object').columns

# %% [markdown]
# **Why scaling**
#
# - Scaling presreve the numerical statbility across the columns
#
#     - Ex: Age: 20  Salary: 50000 Exp:2
#
#     - difrent columns having the different scale(limit)
#
#     - we want to keep all the columns under same limit
#
#     - if wedont keep under same scale some Ml algo feels salary is the importnt columns
#          - because of the highest value
#
# **Fster training**
#
#  - Some of ML algorithms like **KNN, KEMEANS, SVM** are distance based algorithms
#
#  - if we lower the vaules the caluculation are fast
#
#  - In every Model development will do math calculations
#
#  - In order to increase the fastness(optimization) scaling is very helpful

# %% [markdown]
# **Z scale**

# %% [markdown]
# ![image.png](attachment:ac611a43-6bee-4da8-bc9a-83a4965c6199.png)![image.png](attachment:26bf2fd3-5159-4e52-b063-efcd1acdc02b.png)

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df['prevailing_wage']
# Step-1: wage_mean=wage_data.mean()
# step-2: wage_sd
# step-3: Nr=wage_data-wage_mean
# step-4: Nr/wage_sd

# %%
wage_mean = wage_data.mean()
wage_sd = wage_data.std()
Nr = wage_data - wage_mean
wage_z=score = Nr / wage_sd

# %%
# old_data:wage_data
# z_data  : wage_z
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(wage_z)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(wage_z,vert=False)
plt.show()

# %% [markdown]
# **Normallization**

# %% [markdown]
# - sklearn
#
#     - preprocessing
#
#         - StatndardScalar
#
#             - fit_transform

# %%
from sklern.preprocessing import StatndartScalar
ss=StatndardScalar
wage_data_ss=ss.fit_transform(visa_df[['prevaling_wage']])

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(wage_z)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(wage_z,vert=False)
plt.show()

# %% [markdown]
# **Normallization**

# %%
# step-1: wage_min
# step-2: wage_max
# step-3: Nr=wage_data-wage_min
# step-4: Dr= wage_max-wage_min
# step-5: wage_norm=Nr/Dr

# %%
wage_min=wage_data.min()
wage_max=wage_data.max()
Nr=wage_data-wage_min
Dr=wage_max-wage_min
wage_norm=Nr/Dr

# %% [markdown]
# # StandardScalar is called as a z score
# # MinMaxScalar is called as Norm 0 to 1
#
#  - sklearn
#
#     - preprocessing
#
#         - MinmaxScalar
#
#             - fit_trainform
