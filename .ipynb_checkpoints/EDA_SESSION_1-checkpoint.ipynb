# %%
import pandas as pd

# %%
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %% [markdown]
# **step-1:Read the packeges**

# %%
import numpy as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **step-2:Read the datasets**

# %%
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
visa_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
#       2 visa_df
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'read_csv'

# %%
bank_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
n

# %% [markdown]
# **step-3:Data quik**

# %% [markdown]
# us visa_df
#
# - visa_df.shape
#
# - visa_df.size
#
# - head
#
# - teil
#
# - dtypes
#
# - columns
#
# - isnull
#
# - info

# %%
visa_df.shape
#print(f'The number of rows are' : {0})
#print(f'The numbers of columns are' : {1})
# Out:
# (25480, 12)

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
visa_df.size
# Number of columns
# Out:
# 305760

# %%
cols=visa_df.columns
cols
# what are the columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=list(cols)
cols.index('yr_of_estab')
# Out:
# 6

# %%
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df.tail(3)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25477   Certified
# 25478   Certified
# 25479   Certified

# %%
# How you are seeing a df in the numpy language
# pandas === Numpy
# I df 25480  rows 12 columns 25480x12
# Numpy : Bro i have a array having 12 values :12 columns
#         these list are repeating 25480 crime


np.array([[1,2,3,4]]).shape # I have a list of 4 values 1 time
np.array([[1,2,3,4],[10,20,30,40]]).shape # I have a list of 4 values 2 times
# 4 columns 2 rows
# Out:
# (2, 4)

# %%
#[[1,2,3............12],[],[]...........25480]
visa_df # pandas
visa_df.values # numpy arrays
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %% [markdown]
# **loc-iloc**

# %%
#visa_df.iloc[rows,columns]
#visa_df.iloc[start:stop:end,start:stop:end]
visa_df.iloc[2:6,3:7]
# rows: 2:6 2,3,4,5
# columns: 3:7, 3,4,5,6
# Out:
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
# 5                  Y                     N             2339         2012

# %%
# loc will use ful we can provide direct columns names
# no need of indexes
cols=['has_job_experience','requires_job_training']
visa_df.iloc[2:6,3:7]
# Out:
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
# 5                  Y                     N             2339         2012

# %%
visa_df.iloc[2:6,3:7]
cols=['has_job_experience','requires_job_training']
visa_df.iloc[2:6,cols]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 visa_df.iloc[2:6,3:7]
#       2 cols=['has_job_experience','requires_job_training']
# ----> 3 visa_df.iloc[2:6,cols]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._getitem_tuple(self, tup)
#    1690 def _getitem_tuple(self, tup: tuple):
# -> 1691     tup = self._validate_tuple_indexer(tup)
#    1692     with suppress(IndexingError):
#    1693         return self._getitem_lowerdim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 for i, k in enumerate(key):
#     966     try:
# --> 967         self._validate_key(k, i)
#     968     except ValueError as err:
#     969         raise ValueError(
#     970             "Location based indexing can only have "
#     971             f"[{self._valid_types}] types"
#     972         ) from err
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1609, in _iLocIndexer._validate_key(self, key, axis)
#    1607 # check that the key has a numeric dtype
#    1608 if not is_numeric_dtype(arr.dtype):
# -> 1609     raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1611 # check that the key does not exceed the maximum size of the index
#    1612 if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
#
# IndexError: .iloc requires numeric indexers, got ['has_job_experience' 'requires_job_training']

# %%
visa_df.iloc[[100,200,300]]
visa_df.iloc[[100,200,300],:3]
visa_df.iloc[[100,200,300],[3,9]]
# Out:
#     has_job_experience unit_of_wage
# 100                  Y         Year
# 200                  Y         Year
# 300                  Y         Year

# %%
# Every student should understand
# 1D and 2D
# list [] Numpy : 1D pandas === series
# list [[]] Numpy : 2D pandas ==== dataframe

# %%
visa_df # df: columns names
visa_df['continent'] # series no column
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df
visa_df['continent']
visa_df[['continent']]
rows=[100,200,300]
visa_df.iloc[rows,3]
visa_df.iloc[rows,3]
visa_df.loc[rows,'continent']
visa_df.loc[rows,['continent']]
# Out:
#     continent
# 100      Asia
# 200      Asia
# 300      Asia

# %%
visa_df # df  2d
visa_df.values # arrays  2d 
# there are 12 columns
# a list has 12 values 
# list is repeating 25480 rows
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa_df['continent']
visa_df['continent'].values # raw data
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df[['continent','case_status']]
visa_df[['continent','case_status']].values
# Out:
# array([['Asia', 'Denied'],
#        ['Asia', 'Certified'],
#        ['Asia', 'Denied'],
#        ...,
#        ['Asia', 'Certified'],
#        ['Asia', 'Certified'],
#        ['Asia', 'Certified']], shape=(25480, 2), dtype=object)

# %%
# 1D is only one list : Raw data of a specific column
visa_df['continent'].values # [25480]

# 2d is a list has 2 values : DF 2 column
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df['continent'] # S
visa_df[['continnet']] # D
visa_df.iloc[[100,200,300],3] # S
visa_df.iloc[[100,200,300],[3]] # D
visa_df.loc[[100,200,300],'continnet'] # S
visa_df.loc[[100,200,300],['continnet']] # D

# %% [markdown]
# **Datatypes**

# %% [markdown]
# - every series is a key value pair
#
# - every series is dictionary
#
# - in dictionary if we want keys: .keys()
#
# - in dictionary if we want values: .values

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# **Task-1**

# %%
keys=visa_df.dtypes.keys().tolist()
values=visa_df.dtypes.values.tolist()
pd.DataFrame(zip(keys,values),columns=['Name','Data type'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 3
#       1 keys=visa_df.dtypes.keys().tolist()
#       2 values=visa_df.dtypes.values.tolist()
# ----> 3 pd.DataFrame(zip(keys,values),columns=['Name','Data type'])
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'DataFrame'

# %%
visa_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
df=pd.DataFrame(visa_df.dtypes).reset_index()
df.columns=['Name','Data type']
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df=pd.DataFrame(visa_df.dtypes).reset_index()
#       2 df.columns=['Name','Data type']
#       3 df
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'DataFrame'

# %% [markdown]
# **Task-2**

# %%
visa_df.dtypes
# idea 
# extract keys and values
# apply the for loop on values
# for i,j in zip(values,keys):
#  if i =='object':
#      j  

keys=visa_df.dtypes.keys().tolist()
values=visa_df.dtypes.values.tolist()
cat,num=[],[]
for i,j in zip(keys,values):
    if j=='object':
        cat.append(i)
    else:
        num.append(j)
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  [dtype('int64'), dtype('int64'), dtype('float64')])

# %% [markdown]
# **Select_dtypes**

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')
