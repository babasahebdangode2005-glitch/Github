# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\winequality_red.csv")
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
cosine simalirity
# Out:
#   Cell In[4], line 1
#     cosine similirity
#            ^
# SyntaxError: invalid syntax

# %%
                                    Data read
                                        |
                                    Data cleaning
                                        |
                                    Data Analysis
                                        |
                                    Feature engineering
                                        |
                                    Feature selection
                                        |
                                    Model development
                                        |
                                    Model evaluation
                                        |
                                    Model turing
                                        |
                                    Model delpoyment

# %% [markdown]
# **Feature Engineering**
#
# - so far we have performad feature analysis
#
#  - Data frame qucik checks
#
#  - Numerical columns analysis

# %% [markdown]
# **Feature Engineering**
#
# - So far we have performed feature analysis
#
#     - Data frame qucik checks
#
#     - Categoroical column analsyis
#
#     - Bar charts, pie charts
#
#     - Numerical coluen analysis
#
#     - Histograms, box plots, outliers
#
#     - Bi-multi variate analysis
#
#     - correlation etc
#
# - Now we need to lears Feature Engineering
#
#     - we will creats a new colums fer better ML models
#
#     - we will perform the **Encoding**, which convert: categorical to Numerical data
#
#     - we will do data **transformations**
#
#     - we will perfors **Scaling: Standardization and totalization**
#
#     - we will perform Scaling: **Standardization and Normalization**
#
#     - we will perform the **msissing value analayis**
#
# - Simply feature engineering means our data will be mutified

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
num=visa_df.select_dtypes(exclude='object').columns
cat=visa_df.select_dtypes(include='object').columns

# %%
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Case_status**

# %%
# first check how many unique lables are there in case_status
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# cerate  a dictionary
d={'Certified':0,'Denied':1}

# %%
# map the above the dictionary with original columns
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
labels=sorted(visa_df['education_of_employee'].unique())
d={j:i for i,j in enumerate(labels)}
visa_df['education_of_employee'].map(d)
# Out:
# 0        2
# 1        3
# 2        0
# 3        0
# 4        3
#         ..
# 25475    0
# 25476    2
# 25477    3
# 25478    3
# 25479    0
# Name: education_of_employee, Length: 25480, dtype: int64

# %%
d
# Out:
# {"Bachelor's": 0, 'Doctorate': 1, 'High School': 2, "Master's": 3}

# %% [markdown]
# - there are two encodings
#
#   - LabelEncoding
#
#     - OrdinalEncoder

# %%
Education    LabelEncoder     Ordinal Encoder
==========================================================
HighSchool      1               0

Bachelor        0               1

Masters         2               2

PH.D            3               3

  

1  0  2   3===> ML model sees this: 3>2>1>0

Which indicates: PH.D>Masters>Highschool>Batchelors
# Out:
#   Cell In[21], line 1
#     Education    LabelEncoder     Ordinal Encoder
#                  ^
# SyntaxError: invalid syntax

# %%
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
- sklearn: **package**

    - perprocessing: **module**

        - LabelEncoder: **class**

             - fit_transform: **method**


import sklearn
sklearn.preprocessing

from sklearn import preprocessing
dir(preprocessing): LabelEncoder
preprocessing.LabelEncoder

from sklearn preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()

# Read the class
# save the class
# apply the fit transform
# Out:
#   Cell In[23], line 1
#     - sklearn: **package**
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()
# Out:
#   Cell In[24], line 1
#     from sklearn preprocessing import LabelEncoder
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# **fit transform**
#
#   - fit: created a dictonary(find something)
#
#   - transform:usnig above finding we are modify the data
#
# from sklearn.module import class
#
# va=class()
#
# va.fit or va.fit_transform

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **LabelEncoder**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder
le.fit_transform(visa_df['case_status'])
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")

# %%
# read the data again
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]: # Dont consider caseID
    visa_df[i]=le.fit_transform(visa_df[i])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# Read the data again
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in cat[1:]: # Dont consider caseID
    visa_df[i]=oe.fit_transform(visa_df[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 4
#       2 oe=OrdinalEncoder()
#       3 for i in cat[1:]: # Dont consider caseID
# ----> 4     visa_df[i]=oe.fit_transform(visa_df[i])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# Read the data again
visa_df=pd.read_csv(r"C:\Users\hp-440 G6\OneDrive\Documents\Data_files 1\Visadataset.csv")

# %% [markdown]
# **pd.get_dummies**

# %% [markdown]
# - get dummies is a way to represent the categorical columns to numerical
#
# - first it will check what are the lables in a columns
#
# - for example case status has two lables
#
#     - Defined and Certified
#
# - so it will create two new columns based on labels
#
#     col1: case_status_Denied
#     col2: case_status_Certified
#
#
#  case_status   | case_status_Denied  | cae_status_Ceritfied
#     -          |      -              |        -
#  Denied        |      1              |        0
#  Certified     |      0              |        1
#  Certified     |      0              |        1
#
#
# **It is also called as one Hot Encoder**
#
# - It makes new columns are independent each other
#
# - Some of ML algorithms expect that columns should be **independent** each other

# %%
pd.get_dummies(visa_df['case_status'],
               dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]
